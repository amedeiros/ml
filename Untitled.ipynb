# %%
import pandas
from sklearn.linear_model import LinearRegression as Model
import pprint
import matplotlib
import numpy as np

def train(features, target):
    model = Model()
    model.fit(features, target)
    return model

def predict(model, new_features):
    return model.predict(new_features)

data = pandas.read_csv('/mnt/c/Users/Andrew/Documents/code/python_projects/ml/alerts.csv')
data.describe()
# We make a 80/20% train/test split of the data
data_train = data[:int(0.8*len(data))]
data_test  = data[int(0.2*len(data)):]
data_train.describe()
# Out:
#           fromPort        toPort
# count   200.000000    200.000000
# mean   1202.615000   4084.240000
# std    1590.580418  12702.338954
# min      -1.000000     -1.000000
# 25%      23.000000     55.000000
# 50%     389.000000    445.000000
# 75%    3306.000000   3306.000000
# max    5432.000000  65535.000000
